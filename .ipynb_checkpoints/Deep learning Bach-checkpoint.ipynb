# %% [markdown]
# # Deep learning Bach. A step-by-step guide.
#
# I decided to merge two of my great passions: for Artificial Intelligence and for Bach music and try to guide You step-by-step through creating a computer system, which by examining Bach's collected works learns itself to compose "like Bach"... Seriously, at the end of this tutorial you will have a working artificial composer and hopefuly you will also understand how and why it works. And I am not going to lie to you: similar systems of course already exist, created by very smart university and corporate reserchers, but also by hobbyists.
#
# We live in exciting times. Amount of data available on-line in public domain is incredible and tools that allow to manipulate that data in really interesting ways (read: Machine Learning) matured. One thing in all of that is really to be thankful for: somehow the idea of sharing prevails and lot of extremely valuable stuff just lies there, waiting to be used and very smart people spend incredible amounts of their time making even more stuff publicly available and understandable. Kudos. I owe them. Hence this guide.
#
# Callout: Why Bach?
#
# Callout: What is a Machine Learning / Deep Learning
#
# So, who is the audience of this guide?
#
# Cerainly you are not an expert in deep learning nor in musicology. You
#
# So, what are we going to do?
#
# Lets try to sketch
#
# ## Plan of attack
#
# As always divide and concquer is highly succesful strategy, so let's try:
#
# 1. We will start by creating a workbench we're going to use.
# 2. Then we need to get a lot of example data to teach our composer
# 3. Understand the data enough to make it useful
# 4. Prepare it so it's suitable for ML
# 5. Build a neural network
# 6. And teach it using the data we prepared
# 7. Paradoxically, this is not the end. We now need to uncover all that innate knowledge and make it express itself in writing
# 8. Now, let's try to ask it to compose something for us
# 9. Turn that partiture into playable MIDI file and...
# 10. Finally, play it!
#
# Callout: Useful links.

# %%
import numpy as np
import glob
import sys
import collections
import random
import math
from os.path import basename
from itertools import permutations

vocabulary_size = 30**4
MAX_VOICES = 4

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

def permutate(s, pat):
    assert len(s) == len(pat), "string len: {} != pattern len: {}".format(len(s), len(pat))
    r = []
    for ind in pat:
        r.append(s[ind])
    return "".join(r)

def read_data_files(path, validation=True):
    """Read data files according to the specified glob pattern
    Optionnaly set aside the last file as validation data.
    No validation data is returned if there are 5 files or less.
    :param directory: for example "data/*.txt"
    :param validation: if True (default), sets the last file aside as validation data
    :return: training data, validation data, list of loaded file names with ranges
     If validation is
    """
    codetext = []
    opusranges = []
    bachlist = glob.glob(path + '/**/*.txt', recursive=True)
    for bachfile in bachlist:
        bachtext = open(bachfile, "r", encoding='utf8')
        start = len(codetext)
        bars = (bachtext.read()).split("!")
        bars2 = []
        nb_voices = len(bars[0])
        if nb_voices<=MAX_VOICES:
            print("Loading file: {} ; {} voices".format(bachfile, nb_voices))
            for bar in bars: 
                bar2 = bar.ljust(MAX_VOICES, " ")
                #print("'{}', '{}'".format(bar, bar2))
                bars2.append(bar2)
            #print("bars2:", bars2)
            codetext.extend(bars2)
            end = len(codetext)
            opusranges.append({"start": start, "end": end, "name": basename(bachfile).split(".")[0]})
            bachtext.close()

            patterns = list(permutations(range(MAX_VOICES)))

            for pattern_no in range(1,len(patterns)):
                start2 = len(codetext)
                bars = []
                for j in range(start, end-1): #iterate over the whole opus except the final divider ("********")
                    #print(codetext[j], patterns[pattern_no])
                    bars.append(permutate(codetext[j],patterns[pattern_no]))
                assert codetext[end-1] == "********", "expecting '********', instead '{}'".format(codetext[end])
                bars.append(codetext[end-1]) 
                codetext.extend(bars)
                end2 = len(codetext)
                opusranges.append({"start": start2, "end": end2, "name": "Perm"+str(pattern_no)+basename(bachfile).split(".")[0]})
        else:
            print("Skipping file: {} ; {} voices".format(bachfile, nb_voices))
    if len(opusranges) == 0:
        sys.exit("No training data has been found. Aborting.")
    
    total_len = len(codetext)
    
    data, count, dictionary, reverse_dictionary = build_dataset(codetext)
    
    # For validation, use roughly 90K of text,
    # but no more than 10% of the entire text
    # and no more than 1 book in 5 => no validation at all for 5 files or fewer.

    # 10% of the text is how many files ?
    validation_len = 0
    nb_opus1 = 0
    for opus in reversed(opusranges):
        validation_len += opus["end"]-opus["start"]
        nb_opus1 += 1
        if validation_len > total_len // 10:
            break

    # 90K of text is how many books ?
    validation_len = 0
    nb_opus2 = 0
    for opus in reversed(opusranges):
        validation_len += opus["end"]-opus["start"]
        nb_opus2 += 1
        if validation_len > 90*1024:
            break

    # 20% of the books is how many books ?
    nb_opus3 = len(opusranges) // 5

    # pick the smallest
    nb_opus = min(nb_opus1, nb_opus2, nb_opus3)

    if nb_opus == 0 or not validation:
        cutoff = total_len
    else:
        cutoff = opusranges[-nb_opus]["start"]
    validata = data[cutoff:]
    codedata = data[:cutoff]
    return data, codedata, validata, opusranges, count, dictionary, reverse_dictionary

# %%
# %pwd
# Out:
# 'C:\\Users\\krzysztof.pieranski\\Documents\\ml\\deepbach'

# %%
PATH = ".\\txt"

data, codetext, valitext, opusranges, count, dictionary, reverse_dictionary = read_data_files(PATH, validation=True)

#data, count, dictionary, reverse_dictionary = build_dataset(dypthongs)
#print('Most common words (+UNK)', count[:5])
#print('Sample data', data[:10])
# Out:
# Skipping file: .\txt\major\1\bwv806.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv809.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv815.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv816.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv817.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv846.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv848.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv850.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv852.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv854.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv856.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv858.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv860.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv862.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv864.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv866.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv868.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv870.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv872.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv874.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv876.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv878.txt ; 8 voices
# Skipping file: .\txt\major\1\bwv880.txt ; 8 voices
# Loading file: .\txt\major\1\cs6-3cou.txt ; 1 voices
# Loading file: .\txt\major\1\vp3-6gig.txt ; 1 voices
# Loading file: .\txt\major\1\vs3-4alg.txt ; 1 voices
# Skipping file: .\txt\major\1\Wtcii09b.txt ; 8 voices
# Skipping file: .\txt\major\1\Wtcii11b.txt ; 8 voices
# Skipping file: .\txt\major\1\Wtcii13b.txt ; 8 voices
# Skipping file: .\txt\major\1\Wtcii15b.txt ; 8 voices
# Skipping file: .\txt\major\10\bwv0212.txt ; 10 voices
# Skipping file: .\txt\major\10\bwv651.txt ; 10 voices
# Skipping file: .\txt\major\11\bwv0202.txt ; 11 voices
# Skipping file: .\txt\major\13\bburg14a.txt ; 13 voices
# Skipping file: .\txt\major\13\bburg14h.txt ; 13 voices
# Skipping file: .\txt\major\13\bburg1_1.txt ; 13 voices
# Skipping file: .\txt\major\13\Bburg1_3.txt ; 13 voices
# Skipping file: .\txt\major\13\bjsbmm13.txt ; 13 voices
# Skipping file: .\txt\major\14\COURANTE.txt ; 14 voices
# Skipping file: .\txt\major\14\FORLANE.txt ; 14 voices
# Skipping file: .\txt\major\14\MENUET.txt ; 14 voices
# Skipping file: .\txt\major\14\PASSPIED.txt ; 14 voices
# Skipping file: .\txt\major\15\bjsbmm04.txt ; 15 voices
# Skipping file: .\txt\major\15\bjsbmm06.txt ; 15 voices
# Skipping file: .\txt\major\15\bjsbmm16.txt ; 15 voices
# Skipping file: .\txt\major\15\bjsbmm18.txt ; 15 voices
# Skipping file: .\txt\major\15\bjsbmm19.txt ; 15 voices
# Skipping file: .\txt\major\16\bjsbmm11.txt ; 16 voices
# Skipping file: .\txt\major\16\bjsbmm20.txt ; 16 voices
# Skipping file: .\txt\major\16\bjsbmm23.txt ; 16 voices
# Skipping file: .\txt\major\16\BOURREE.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0205.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0243.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248a.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248b.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248c.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248d.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248e.txt ; 16 voices
# Skipping file: .\txt\major\16\bwv0248f.txt ; 16 voices
# Skipping file: .\txt\major\16\GAVOTTE.txt ; 16 voices
# Skipping file: .\txt\major\16\GIGUE.txt ; 16 voices
# Skipping file: .\txt\major\16\OVERTURE.txt ; 16 voices
# Skipping file: .\txt\major\16\rejouiss.txt ; 16 voices
# Loading file: .\txt\major\2\988-v07.txt ; 2 voices
# Loading file: .\txt\major\2\988-v08.txt ; 2 voices
# Loading file: .\txt\major\2\988-v20.txt ; 2 voices
# Loading file: .\txt\major\2\988-v27.txt ; 2 voices
# Loading file: .\txt\major\2\bwv1075.txt ; 2 voices
# Loading file: .\txt\major\2\bwv1086.txt ; 2 voices
# Loading file: .\txt\major\2\bwv772.txt ; 2 voices
# Loading file: .\txt\major\2\bwv772a.txt ; 2 voices
# Loading file: .\txt\major\2\bwv803.txt ; 2 voices
# Loading file: .\txt\major\2\bwv804.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv806a.txt ; 8 voices
# Skipping file: .\txt\major\2\bwv806b.txt ; 8 voices
# Skipping file: .\txt\major\2\bwv806c.txt ; 8 voices
# Loading file: .\txt\major\2\bwv806d.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv806e.txt ; 8 voices
# Loading file: .\txt\major\2\bwv806f.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv806g.txt ; 8 voices
# Loading file: .\txt\major\2\bwv806h.txt ; 2 voices
# Loading file: .\txt\major\2\bwv806j.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv807g.txt ; 8 voices
# Loading file: .\txt\major\2\bwv808g.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv809a.txt ; 8 voices
# Skipping file: .\txt\major\2\bwv809b.txt ; 8 voices
# Loading file: .\txt\major\2\bwv809c.txt ; 2 voices
# Skipping file: .\txt\major\2\bwv809d.txt ; 8 voices
# Loading file: .\txt\major\2\bwv809g.txt ; 2 voices
# Loading file: .\txt\major\2\bwv810f.txt ; 2 voices
# Loading file: .\txt\major\2\bwv811g.txt ; 2 voices
# Loading file: .\txt\major\2\cs1-3cou.txt ; 2 voices
# Loading file: .\txt\major\2\vp3-5bou.txt ; 2 voices
# Skipping file: .\txt\major\2\Wtcii01a.txt ; 8 voices
# Loading file: .\txt\major\3\988-v02.txt ; 3 voices
# Loading file: .\txt\major\3\988-v03.txt ; 3 voices
# Loading file: .\txt\major\3\988-v09.txt ; 3 voices
# Loading file: .\txt\major\3\988-v13.txt ; 3 voices
# Loading file: .\txt\major\3\988-v19.txt ; 3 voices
# Loading file: .\txt\major\3\988-v24.txt ; 3 voices
# Loading file: .\txt\major\3\bjs1031a.txt ; 3 voices
# Loading file: .\txt\major\3\bjs1031c.txt ; 3 voices
# Loading file: .\txt\major\3\bwv0541f.txt ; 3 voices
# Loading file: .\txt\major\3\bwv0541p.txt ; 3 voices
# Loading file: .\txt\major\3\bwv1027.txt ; 3 voices
# Loading file: .\txt\major\3\bwv525-1.txt ; 3 voices
# Loading file: .\txt\major\3\bwv525-3.txt ; 3 voices
# Loading file: .\txt\major\3\cs1-1pre.txt ; 3 voices
# Loading file: .\txt\major\3\cs1-2all.txt ; 3 voices
# Loading file: .\txt\major\3\cs1-5men.txt ; 3 voices
# Loading file: .\txt\major\3\cs1-6gig.txt ; 3 voices
# Loading file: .\txt\major\3\cs3-5bou.txt ; 3 voices
# Loading file: .\txt\major\3\cs4-4sar.txt ; 3 voices
# Loading file: .\txt\major\3\cs6-1pre.txt ; 3 voices
# Loading file: .\txt\major\3\pfa-1pre.txt ; 3 voices
# Loading file: .\txt\major\3\pfa-3alg.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_1c.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_2a.txt ; 3 voices
# Skipping file: .\txt\major\3\sonat_2b.txt ; 8 voices
# Loading file: .\txt\major\3\sonat_2d.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_3a.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_3b.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_3d.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_4c.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_6a.txt ; 3 voices
# Loading file: .\txt\major\3\sonat_6e.txt ; 3 voices
# Loading file: .\txt\major\3\vp3-2lou.txt ; 3 voices
# Skipping file: .\txt\major\3\Wtcii03b.txt ; 8 voices
# Loading file: .\txt\major\3\Wtcii21b.txt ; 3 voices
# Loading file: .\txt\major\4\988-v04.txt ; 4 voices
# Loading file: .\txt\major\4\988-v10.txt ; 4 voices
# Loading file: .\txt\major\4\988-v16.txt ; 4 voices
# Loading file: .\txt\major\4\988-v23.txt ; 4 voices
# Loading file: .\txt\major\4\988-v30.txt ; 4 voices
# Skipping file: .\txt\major\4\bwv1028.txt ; 8 voices
# Loading file: .\txt\major\4\bwv1074.txt ; 4 voices
# Loading file: .\txt\major\4\bwv552p.txt ; 4 voices
# Loading file: .\txt\major\4\bwv652.txt ; 4 voices
# Loading file: .\txt\major\4\bwv653-2.txt ; 4 voices
# Loading file: .\txt\major\4\bwv653.txt ; 4 voices
# Loading file: .\txt\major\4\bwv662.txt ; 4 voices
# Loading file: .\txt\major\4\bwv663.txt ; 4 voices
# Skipping file: .\txt\major\4\bwv664.txt ; 8 voices
# Skipping file: .\txt\major\4\bwv971a.txt ; 8 voices
# Loading file: .\txt\major\4\cs1-4sar.txt ; 4 voices
# Loading file: .\txt\major\4\cs3-1pre.txt ; 4 voices
# Loading file: .\txt\major\4\cs3-2all.txt ; 4 voices
# Loading file: .\txt\major\4\cs3-4sar.txt ; 4 voices
# Loading file: .\txt\major\4\cs3-6gig.txt ; 4 voices
# Loading file: .\txt\major\4\cs4-1pre.txt ; 4 voices
# Loading file: .\txt\major\4\cs4-5bou.txt ; 4 voices
# Loading file: .\txt\major\4\cs6-4sar.txt ; 4 voices
# Loading file: .\txt\major\4\cs6-5gav.txt ; 4 voices
# Loading file: .\txt\major\4\cs6-6gig.txt ; 4 voices
# Loading file: .\txt\major\4\pfa-2fug.txt ; 4 voices
# Loading file: .\txt\major\4\vp3-1pre.txt ; 4 voices
# Loading file: .\txt\major\4\vp3-3gav.txt ; 4 voices
# Loading file: .\txt\major\4\vp3-4min.txt ; 4 voices
# Loading file: .\txt\major\4\vs1-3sic.txt ; 4 voices
# Loading file: .\txt\major\4\vs2-3and.txt ; 4 voices
# Loading file: .\txt\major\4\vs3-1ada.txt ; 4 voices
# Loading file: .\txt\major\4\vs3-2fug.txt ; 4 voices
# Loading file: .\txt\major\4\vs3-3lar.txt ; 4 voices
# Loading file: .\txt\major\4\Wtcii01b.txt ; 4 voices
# Loading file: .\txt\major\4\Wtcii05b.txt ; 4 voices
# Loading file: .\txt\major\4\Wtcii07b.txt ; 4 voices
# Loading file: .\txt\major\4\Wtcii17b.txt ; 4 voices
# Skipping file: .\txt\major\5\bjsbmm02.txt ; 5 voices
# Skipping file: .\txt\major\5\bjsbmm17.txt ; 5 voices
# Skipping file: .\txt\major\5\bwv1077.txt ; 5 voices
# Skipping file: .\txt\major\5\bwv552f.txt ; 5 voices
# Skipping file: .\txt\major\5\bwv654.txt ; 5 voices
# Skipping file: .\txt\major\6\bjsbmm10.txt ; 6 voices
# Skipping file: .\txt\major\6\bwv1076.txt ; 6 voices
# Skipping file: .\txt\major\6\bwv1087.txt ; 6 voices
# Skipping file: .\txt\major\6\bwv655.txt ; 6 voices
# Skipping file: .\txt\major\6\bwv657.txt ; 6 voices
# Skipping file: .\txt\major\6\jsb212sf.txt ; 6 voices
# Skipping file: .\txt\major\7\bwv1041b.txt ; 7 voices
# Skipping file: .\txt\major\7\bwv668.txt ; 7 voices
# Skipping file: .\txt\major\7\bwv988.txt ; 7 voices
# Skipping file: .\txt\major\8\AIR.txt ; 8 voices
# Skipping file: .\txt\major\8\bjsbmm05.txt ; 8 voices
# Skipping file: .\txt\major\8\bwv1072.txt ; 8 voices
# Skipping file: .\txt\major\8\bwv656.txt ; 8 voices
# Skipping file: .\txt\major\9\bjsbmm07.txt ; 9 voices
# Skipping file: .\txt\major\9\bjsbmm12.txt ; 9 voices
# Skipping file: .\txt\major\9\bjsbmm14.txt ; 9 voices
# Skipping file: .\txt\major\9\bwv29sin.txt ; 9 voices
# Skipping file: .\txt\major\9\bwv667.txt ; 9 voices
# Skipping file: .\txt\minor\1\bwv807.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv808.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv810.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv811.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv812.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv813.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv814.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv847.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv849.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv851.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv853.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv855.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv857.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv859.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv861.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv863.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv865.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv867.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv869.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv871.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv873.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv875.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv877.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv879.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv881.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv903.txt ; 8 voices
# Skipping file: .\txt\minor\1\bwv971.txt ; 8 voices
# Loading file: .\txt\minor\1\cs4-6gig.txt ; 1 voices
# Loading file: .\txt\minor\1\cs5-4sar.txt ; 1 voices
# Skipping file: .\txt\minor\1\cs5-5gav.txt ; 8 voices
# Loading file: .\txt\minor\1\cs5-6gig.txt ; 1 voices
# Loading file: .\txt\minor\1\fp-1all.txt ; 1 voices
# Loading file: .\txt\minor\1\fp-2cou.txt ; 1 voices
# Loading file: .\txt\minor\1\fp-3sar.txt ; 1 voices
# Loading file: .\txt\minor\1\fp-4bou.txt ; 1 voices
# Loading file: .\txt\minor\1\vp1-2ald.txt ; 1 voices
# Loading file: .\txt\minor\1\vp1-4cod.txt ; 1 voices
# Loading file: .\txt\minor\1\vp1-6sad.txt ; 1 voices
# Loading file: .\txt\minor\1\vp2-4gig.txt ; 1 voices
# Skipping file: .\txt\minor\1\Wtcii08b.txt ; 8 voices
# Skipping file: .\txt\minor\1\Wtcii10b.txt ; 8 voices
# Skipping file: .\txt\minor\1\Wtcii11a.txt ; 8 voices
# Skipping file: .\txt\minor\1\Wtcii12b.txt ; 8 voices
# Skipping file: .\txt\minor\1\Wtcii14b.txt ; 8 voices
# Skipping file: .\txt\minor\1\Wtcii16b.txt ; 8 voices
# Skipping file: .\txt\minor\10\BADINERI.txt ; 10 voices
# Skipping file: .\txt\minor\10\bjsbmm08.txt ; 10 voices
# Skipping file: .\txt\minor\10\bwv1063.txt ; 10 voices
# Skipping file: .\txt\minor\10\POLONAIS.txt ; 10 voices
# Skipping file: .\txt\minor\10\RONDEAU.txt ; 10 voices
# Skipping file: .\txt\minor\11\Bburg1_2.txt ; 11 voices
# Skipping file: .\txt\minor\12\bjsbmm15.txt ; 12 voices
# Skipping file: .\txt\minor\13\bjsbmm01.txt ; 13 voices
# Skipping file: .\txt\minor\13\bwv_1060.txt ; 13 voices
# Skipping file: .\txt\minor\15\bjsbmm03.txt ; 15 voices
# Loading file: .\txt\minor\2\1079-03.txt ; 2 voices
# Loading file: .\txt\minor\2\1079-04.txt ; 1 voices
# Loading file: .\txt\minor\2\1080-c12.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v01.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v05.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v11.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v14.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v17.txt ; 2 voices
# Loading file: .\txt\minor\2\988-v29.txt ; 2 voices
# Loading file: .\txt\minor\2\997-1pre.txt ; 2 voices
# Loading file: .\txt\minor\2\997-4gig.txt ; 2 voices
# Loading file: .\txt\minor\2\997-5dou.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv582.txt ; 1 voices
# Loading file: .\txt\minor\2\bwv630sc.txt ; 1 voices
# Loading file: .\txt\minor\2\bwv658.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv666.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv784.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv802.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv805.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv805th.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv806i.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv807a.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv807b.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv807c.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv807d.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv807e.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv807f.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv807h.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv808a.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv808b.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv808c.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv808d.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv808e.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv808f.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv808h.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv809e.txt ; 2 voices
# Loading file: .\txt\minor\2\bwv809f.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv810a.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv810b.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv810c.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv810d.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv810e.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv810g.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv811a.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv811b.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv811c.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv811d.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv811e.txt ; 8 voices
# Loading file: .\txt\minor\2\bwv811f.txt ; 2 voices
# Skipping file: .\txt\minor\2\bwv811h.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv906a.txt ; 8 voices
# Skipping file: .\txt\minor\2\bwv906b.txt ; 8 voices
# Loading file: .\txt\minor\2\cs5-2all.txt ; 2 voices
# Loading file: .\txt\minor\2\cs5-3cou.txt ; 2 voices
# Skipping file: .\txt\minor\2\sonat_6c.txt ; 8 voices
# Loading file: .\txt\minor\2\vs2-4alg.txt ; 2 voices
# Skipping file: .\txt\minor\2\Wtcii10a.txt ; 8 voices
# Loading file: .\txt\minor\2\Wtcii24a.txt ; 2 voices
# Loading file: .\txt\minor\3\1079-02.txt ; 3 voices
# Loading file: .\txt\minor\3\1079-05.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v06.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v12.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v15.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v18.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v21.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v25.txt ; 3 voices
# Loading file: .\txt\minor\3\988-v26.txt ; 3 voices
# Loading file: .\txt\minor\3\bjs1031b.txt ; 3 voices
# Loading file: .\txt\minor\3\bwv1029.txt ; 3 voices
# Skipping file: .\txt\minor\3\bwv1030.txt ; 8 voices
# Loading file: .\txt\minor\3\bwv525-2.txt ; 3 voices
# Loading file: .\txt\minor\3\bwv537.txt ; 3 voices
# Loading file: .\txt\minor\3\bwv630sc.txt ; 3 voices
# Loading file: .\txt\minor\3\bwv660.txt ; 3 voices
# Skipping file: .\txt\minor\3\bwv686.txt ; 8 voices
# Loading file: .\txt\minor\3\bwv733.txt ; 3 voices
# Loading file: .\txt\minor\3\bwv801.txt ; 3 voices
# Loading file: .\txt\minor\3\cs2-3cou.txt ; 3 voices
# Loading file: .\txt\minor\3\cs2-5men.txt ; 3 voices
# Loading file: .\txt\minor\3\cs2-6gig.txt ; 3 voices
# Loading file: .\txt\minor\3\cs4-3cou.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_1a.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_1b.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_1d.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_2c.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_3c.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_4a.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_4b.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_4d.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_5a.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_5b.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_5c.txt ; 3 voices
# Loading file: .\txt\minor\3\sonat_5d.txt ; 3 voices
# Skipping file: .\txt\minor\3\sonat_6b.txt ; 8 voices
# Loading file: .\txt\minor\3\sonat_6d.txt ; 3 voices
# Loading file: .\txt\minor\3\vp1-3co.txt ; 3 voices
# Loading file: .\txt\minor\3\vp1-8tbd.txt ; 3 voices
# Loading file: .\txt\minor\3\vp2-2cou.txt ; 3 voices
# Loading file: .\txt\minor\3\vs1-4prs.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii04b.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii06b.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii18b.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii19b.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii20b.txt ; 3 voices
# Loading file: .\txt\minor\3\Wtcii24b.txt ; 3 voices
# Loading file: .\txt\minor\4\1079-04.txt ; 4 voices
# Loading file: .\txt\minor\4\1080-c01.txt ; 4 voices
# Loading file: .\txt\minor\4\1080-c02.txt ; 4 voices
# Loading file: .\txt\minor\4\1080c02b.txt ; 4 voices
# Loading file: .\txt\minor\4\988-aria.txt ; 4 voices
# Loading file: .\txt\minor\4\988-v22.txt ; 4 voices
# Loading file: .\txt\minor\4\988-v28.txt ; 4 voices
# Loading file: .\txt\minor\4\997-2fug.txt ; 4 voices
# Loading file: .\txt\minor\4\bjsbmm21.txt ; 4 voices
# Loading file: .\txt\minor\4\bjsbmm22.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv1073.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv1074i.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv539.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv582.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv588.txt ; 4 voices
# Loading file: .\txt\minor\4\bwv971.txt ; 3 voices
# Skipping file: .\txt\minor\4\bwv982js.txt ; 8 voices
# Loading file: .\txt\minor\4\cs2-1pre.txt ; 4 voices
# Loading file: .\txt\minor\4\cs2-2all.txt ; 4 voices
# Loading file: .\txt\minor\4\cs2-4sar.txt ; 4 voices
# Loading file: .\txt\minor\4\cs3-3cou.txt ; 4 voices
# Loading file: .\txt\minor\4\cs4-2all.txt ; 4 voices
# Loading file: .\txt\minor\4\cs5-1pre.txt ; 4 voices
# Loading file: .\txt\minor\4\cs6-2all.txt ; 4 voices
# Loading file: .\txt\minor\4\vp1-1al.txt ; 4 voices
# Loading file: .\txt\minor\4\vp1-5sa.txt ; 4 voices
# Loading file: .\txt\minor\4\vp1-7tb.txt ; 4 voices
# Loading file: .\txt\minor\4\vp2-1all.txt ; 4 voices
# Loading file: .\txt\minor\4\vp2-3sar.txt ; 4 voices
# Loading file: .\txt\minor\4\vs1-1ada.txt ; 4 voices
# Loading file: .\txt\minor\4\vs2-1gra.txt ; 4 voices
# Loading file: .\txt\minor\4\vs2-2fug.txt ; 4 voices
# Loading file: .\txt\minor\4\Wtcii02b.txt ; 4 voices
# Loading file: .\txt\minor\4\Wtcii22b.txt ; 4 voices
# Loading file: .\txt\minor\4\Wtcii23b.txt ; 4 voices
# Skipping file: .\txt\minor\5\997-3sar.txt ; 5 voices
# Loading file: .\txt\minor\5\bwv1062.txt ; 4 voices
# Loading file: .\txt\minor\5\bwv1063.txt ; 4 voices
# Skipping file: .\txt\minor\5\bwv659.txt ; 5 voices
# Skipping file: .\txt\minor\5\vp2-5cha.txt ; 5 voices
# Skipping file: .\txt\minor\5\vs1-2fug.txt ; 5 voices
# Skipping file: .\txt\minor\6\1079-03.txt ; 5 voices
# Skipping file: .\txt\minor\6\bwv1041a.txt ; 5 voices
# Skipping file: .\txt\minor\6\bwv1041c.txt ; 5 voices
# Skipping file: .\txt\minor\6\bwv661.txt ; 6 voices
# Skipping file: .\txt\minor\6\bwv665.txt ; 6 voices
# Skipping file: .\txt\minor\6\bwv805.txt ; 5 voices
# Skipping file: .\txt\minor\7\1079-02.txt ; 6 voices
# Skipping file: .\txt\minor\7\1080-c12.txt ; 6 voices
# Skipping file: .\txt\minor\7\bjsbmm09.txt ; 7 voices
# Skipping file: .\txt\minor\7\bwv1041a.txt ; 7 voices
# Skipping file: .\txt\minor\7\bwv1041c.txt ; 7 voices
# Skipping file: .\txt\minor\7\bwv1052a.txt ; 7 voices
# Skipping file: .\txt\minor\8\bwv1078.txt ; 8 voices
# Skipping file: .\txt\minor\9\bwv1062.txt ; 9 voices
# Skipping file: .\txt\minor\9\SARABAND.txt ; 9 voices

# %%
codevector.shape[0]
# Out:
# 5914420

# %%
from tensorflow.contrib.keras import models as tfm
from tensorflow.contrib.keras import layers as tfl
from tensorflow.contrib.keras import optimizers
from tensorflow.contrib.keras import regularizers
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from tensorflow.contrib.keras import wrappers as tfw
import tensorflow as tf
from tensorflow.contrib.keras import backend as K
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

n_vocab = len(dictionary)+1
n_embed_size = 20
p_dropout = 0.0

SEQLEN = 64
BATCHSIZE = 32
INTERNALSIZE = 256
NLAYERS = 3
NB_EPOCHS = 30

def cos_distance(y_true, y_pred):
    y_true = K.l2_normalize(y_true, axis=-1)
    y_pred = K.l2_normalize(y_pred, axis=-1)
    return K.mean(1 - K.sum((y_true * y_pred), axis=-1))

def rnn_minibatch_sequencer(raw_data, batch_size, sequence_size, nb_epochs):
    """
    Divides the data into batches of sequences so that all the sequences in one batch
    continue in the next batch. This is a generator that will keep returning batches
    until the input data has been seen nb_epochs times. Sequences are continued even
    between epochs, apart from one, the one corresponding to the end of raw_data.
    The remainder at the end of raw_data that does not fit in an full batch is ignored.
    :param raw_data: the training text
    :param batch_size: the size of a training minibatch
    :param sequence_size: the unroll size of the RNN
    :param nb_epochs: number of epochs to train on
    :return:
        x: one batch of training sequences
        y: on batch of target sequences, i.e. training sequences shifted by 1
        epoch: the current epoch number (starting at 0)
    """
    data = raw_data
    data_len = data.shape[0]
    print(data_len)
    # using (data_len-1) because we must provide for the sequence shifted by 1 too
    nb_batches = (data_len - 1) // (batch_size * sequence_size)
    assert nb_batches > 0, "Not enough data, even for a single batch. Try using a smaller batch_size."
    rounded_data_len = nb_batches * batch_size * sequence_size
    xdata = np.reshape(data[0:rounded_data_len, :], [batch_size, nb_batches * sequence_size, n_embed_size])
    ydata = np.reshape(data[1:rounded_data_len + 1, :], [batch_size, nb_batches * sequence_size, n_embed_size])

    for epoch in range(nb_epochs):
        for batch in range(nb_batches):
            x = xdata[:, batch * sequence_size:(batch + 1) * sequence_size]
            y = ydata[:, batch * sequence_size:(batch + 1) * sequence_size]
            x = np.roll(x, -epoch, axis=0)  # to continue the text from epoch to epoch (do not reset rnn state!)
            y = np.roll(y, -epoch, axis=0)
            yield x, y, epoch
            
def rnn_validata_sequencer(raw_data, batch_size, sequence_size, nb_epochs):
    """
    Divides the data into batches of sequences so that all the sequences in one batch
    continue in the next batch. This is a generator that will keep returning batches
    until the input data has been seen nb_epochs times. Sequences are continued even
    between epochs, apart from one, the one corresponding to the end of raw_data.
    The remainder at the end of raw_data that does not fit in an full batch is ignored.
    :param raw_data: the training text
    :param batch_size: the size of a training minibatch
    :param sequence_size: the unroll size of the RNN
    :param nb_epochs: number of epochs to train on
    :return:
        x: one batch of training sequences
        y: on batch of target sequences, i.e. training sequences shifted by 1
        epoch: the current epoch number (starting at 0)
    """
    data = raw_data
    data_len = data.shape[0]
    print(data_len)
    # using (data_len-1) because we must provide for the sequence shifted by 1 too
    nb_batches = (data_len - 1) // (batch_size * sequence_size)
    assert nb_batches > 0, "Not enough data, even for a single batch. Try using a smaller batch_size."
    rounded_data_len = nb_batches * batch_size * sequence_size
    xdata = np.reshape(data[0:rounded_data_len, :], [batch_size, nb_batches * sequence_size, n_embed_size])
    ydata = np.reshape(data[1:rounded_data_len + 1, :], [batch_size, nb_batches * sequence_size, n_embed_size])

    for epoch in range(nb_epochs):
        for batch in range(nb_batches):
            x = xdata[:, batch * sequence_size:(batch + 1) * sequence_size]
            y = ydata[:, batch * sequence_size:(batch + 1) * sequence_size]
            x = np.roll(x, -epoch, axis=0)  # to continue the text from epoch to epoch (do not reset rnn state!)
            y = np.roll(y, -epoch, axis=0)
            yield x, y, epoch

def create_model():
# create model
    model = tfm.Sequential()
    #model.add(tfl.Embedding(n_vocab, n_embed_size, weigths = [final_embeddings], trainable = False, input_length = SEQLEN))
    model.add(tfl.LSTM(INTERNALSIZE, return_sequences=True,
               input_shape=(SEQLEN, n_embed_size)))  # returns a sequence of vectors of dimension 32
    model.add(tfl.LSTM(INTERNALSIZE, return_sequences=True))  # returns a sequence of vectors of dimension 32
    #model.add(tfl.LSTM(INTERNALSIZE))  # return a single vector of dimension 32
    model.add(tfl.TimeDistributed(tfl.Dense(n_embed_size, activation='sigmoid')))
    model.compile(loss='mse',
              optimizer='adam',
              metrics=['accuracy'])
    return model

model = create_model()
print(model.summary())

step = 0
for x, y_, epoch in rnn_minibatch_sequencer(codevector, BATCHSIZE, SEQLEN, nb_epochs=NB_EPOCHS):
    print("Traning epoch: {} / batch:{}, samples: {}".format(epoch, step, (epoch+1)*step*BATCHSIZE*SEQLEN))
    print("Loss: {}, Accuracy: {}".format(history[0], history[1]))
    if step % 50 == 0 and len(valitext) > 0:
        print("Traning epoch: {} / batch:{}, samples: {}".format(epoch, step, (epoch+1)*step*BATCHSIZE*SEQLEN))
        vali_x, vali_y, _ = next(rnn_validata_sequencer(valivector, BATCHSIZE, SEQLEN, nb_epochs=NB_EPOCHS)) 
        loss, accuracy = model.evaluate(vali_x, vali_y, verbose =1)
        print("Loss: {}, Accuracy: {}".format(loss, accuracy))       
    step += 1

# %%
# Out:
# [0.96982968, 0.04296875]

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
import tensorflow as tf

batch_size = 128
embedding_size = 20 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  # embeddings = tf.Variable(tf.random_uniform([n_vocab, embedding_size], -1.0, 1.0))
  embeddings = tf.Variable(final_embeddings) #use this to continue learning from the saved checkpoint
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdamOptimizer(0.001).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
from pathlib import Path
outfile = Path(PATH + "\\final_embeddings_3.npy")
final_embeddings = np.load(outfile)

# %%
num_steps = 2001
refresh_freq = 1000

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % refresh_freq == 0:
        if step > 0:
            average_loss = average_loss / refresh_freq
            # The average loss is an estimate of the loss over the last refresh_freq batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        sim = similarity.eval()
        for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 6 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = 'Nearest to %s:' % valid_word
            for k in range(top_k):
                close_word = reverse_dictionary[nearest[k]]
                log = '%s %s,' % (log, close_word)
            print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Nearest to    d:    b,    c,    f, q J\,  P `, m] L,
# Nearest to f   : h   , d   , i   , g   ,   R\, gLa[,
# Nearest to    ]: QUVS, ]_GV,  fb[, `[ I,    _, MT] ,
# Nearest to  L  :  P  ,  S  , ]ebS,    =,  Q  , ZL[O,
# Nearest to    T:  NX , ` M[, JX L,   V ,   S ,  Qkk,
# Nearest to  Q  :  S  ,  P  , ]VYJ,  O  , ZL[O,  XOQ,
# Nearest to [   : Z   , V   , U   , Kg]H, S_D , fb l,
# Nearest to  X  :  Z  ,  V  ,  U  , dd h, lhY ,  Yi[,
# Nearest to   X :   Z ,   V ,   U , ni` , ^Hl , MXi],
# Nearest to    P:    L,    Q,    N,    I,    O,    J,
# Nearest to    a:    _,    c, JV^ , ZmN ,    d, dD \,
# Nearest to  S  :  Q  ,  P  ,  O  ,  L  ,  XOQ, dJ[T,
# Nearest to S   : U   , V   , s da, X   , Q   ,  _Kr,
# Nearest to UNK: W_Wi, MiVb, W[_i,  j n,  `pP, gG _,
# Nearest to   ] :   [ , t  _,  _Oh,   Z , B  ], ^i d,
# Nearest to  E  :  I  ,  J  , a  p, aMQg, eid ,  H J,
# Average loss at step 1000: 8.236681
# Nearest to    d:    b,    c,    f,  P `,    a,    h,
# Nearest to f   : h   , d   , W i , g   ,   R\, m Q ,
# Nearest to    ]: QUVS,    _,  fb[, ]_GV, `[ I, a  o,
# Nearest to  L  :  P  ,     ,  S  ,  G  ,  I  ,  N  ,
# Nearest to    T:   X ,   V ,   S ,  NX ,   J ,   U ,
# Nearest to  Q  :  S  ,  P  ,  L  ,  N  ,  E  ,  J  ,
# Nearest to [   : Z   , Kg]H, X   , V   , U   , S_D ,
# Nearest to  X  :  V  ,  U  ,  Z  ,  O  ,   T ,  W  ,
# Nearest to   X :   V , ni` ,   U ,   Z ,   S ,   Q ,
# Nearest to    P:    L,    N,    Q,    J,    U,    I,
# Nearest to    a:    _,    c, JV^ , ZmN ,    d, E_  ,
# Nearest to  S  :  P  ,  Q  ,  L  ,  U  ,  N  ,  J  ,
# Nearest to S   : V   , Q   , U   , P   ,  T  , L   ,
# Nearest to UNK: W_Wi, MiVb, W[_i,  j n,  `pP, gG _,
# Nearest to   ] :   [ , t  _,   aQ,   Z ,  _Oh,  eTp,
# Nearest to  E  :  L  ,  J  ,  I  ,  S  ,  Q  ,  P  ,
# Average loss at step 2000: 3.783873
# Nearest to    d:    b,    c,    f,  P `,    a,    h,
# Nearest to f   : h   , d   , W i , g   ,   R\, m Q ,
# Nearest to    ]: QUVS,    _,  fb[, ]_GV, `[ I, a  o,
# Nearest to  L  :  I  ,     ,  G  ,  N  ,  K  ,  P  ,
# Nearest to    T:   X ,   V ,   J ,   U ,   O ,   S ,
# Nearest to  Q  :  S  ,  P  ,  J  ,  E  ,  U  ,  I  ,
# Nearest to [   : Z   , Kg]H, S_D , fb l, pLX ,  NN_,
# Nearest to  X  :  E  ,  U  ,  V  ,  J  ,  I  ,  S  ,
# Nearest to   X :   V ,   U ,   S ,   Q ,   L ,   N ,
# Nearest to    P:    N,    Q,    L,    S,    U,    X,
# Nearest to    a:    _,    c, JV^ , ZmN ,    d, E_  ,
# Nearest to  S  :  P  ,  U  ,  J  ,  Q  ,  V  ,  O  ,
# Nearest to S   : V   , Q   , P   , U   , L   ,  T  ,
# Nearest to UNK: W_Wi, MiVb, W[_i,  j n,  `pP, gG _,
# Nearest to   ] :   [ , t  _,   aQ,  _Oh,  eTp, ^i d,
# Nearest to  E  :  X  ,  I  ,  J  ,  Q  ,  D  ,  U  ,

# %%
codevector = np.zeros((len(codetext), embedding_size))
for i in range(len(codetext)):
    codevector[i] = final_embeddings[codetext[i]]

# %%
valivector = np.zeros((len(valitext), embedding_size))
for i in range(len(valitext)):
    valivector[i] = final_embeddings[valitext[i]]

# %%
codevector.shape
# Out:
# (5914420, 20)

# %%
for i in range(16):
    valid_word = reverse_dictionary[valid_examples[i]]
    top_k = 12 # number of nearest neighbors
    nearest = (-sim[i, :]).argsort()[1:top_k+1]
    log = 'Nearest to %s:' % valid_word
    for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
    print(log)
# Out:
# Nearest to    d:    b,    c,    f,  P `,    a,    h, Q Xb, HT V, m] L, aUgQ,  [QE,    i,
# Nearest to f   : h   , d   , W i , g   ,   R\, m Q , b   , n^T , i   , [Y  , iU  , gLa[,
# Nearest to    ]: QUVS,    _,  fb[, ]_GV, `[ I, a  o, []LB, MT] , F[b^, iQZa, QVMS, X Ob,
# Nearest to  L  :  I  ,     ,  G  ,  N  ,  K  ,  P  ,   M ,   K ,    @,  S  ,  B  ,  J  ,
# Nearest to    T:   X ,   V ,   J ,   U ,   O ,   S ,   Q ,   G ,   L ,   P ,   I ,   Z ,
# Nearest to  Q  :  S  ,  P  ,  J  ,  E  ,  U  ,  I  ,  N  ,  L  ,  D  ,  V  ,  O  ,  X  ,
# Nearest to [   : Z   , Kg]H, S_D , fb l, pLX ,  NN_, c\l , mW d, sZ p, X   , oi T, h XX,
# Nearest to  X  :  E  ,  U  ,  V  ,  J  ,  I  ,  S  ,  Q  ,  Z  ,  P  ,   B ,  G  ,  L  ,
# Nearest to   X :   V ,   U ,   S ,   Q ,   L ,   N ,   G ,   P ,   I ,   J , ********,   Z ,
# Nearest to    P:    N,    Q,    L,    S,    U,    X,    J,    V,    R,    I,    O,    G,
# Nearest to    a:    _,    c, JV^ , ZmN ,    d, E_  , dD \, c GS, fm X,  kXL, Z dK,  dYO,
# Nearest to  S  :  P  ,  U  ,  J  ,  Q  ,  V  ,  O  ,  N  ,  G  ,  L  ,  I  ,  E  ,  R  ,
# Nearest to S   : V   , Q   , P   , U   , L   ,  T  ,  M  , I   , ********, N   ,     ,   E ,
# Nearest to UNK: W_Wi, MiVb, W[_i,  j n,  `pP, gG _,  aaI, [[EV, l d`, iX H, lbJ , Vfg ,
# Nearest to   ] :   [ , t  _,   aQ,  _Oh,  eTp, ^i d, B  ],   ` ,  PZ ,   Y ,  Ubk,  U \,
# Nearest to  E  :  X  ,  I  ,  J  ,  Q  ,  D  ,  U  ,  V  ,  L  ,  S  ,  P  ,  G  ,     ,

# %%
final_embeddings[0]
# Out:
# array([ 0.40275112, -0.04863255,  0.30368793,  0.06228257, -0.28215745,
#        -0.04976769,  0.18830134, -0.0575086 ,  0.16519442,  0.07572614,
#        -0.35413435, -0.136016  ,  0.05114105,  0.23464742, -0.01558306,
#         0.21568705,  0.38817203, -0.12697509, -0.40035945, -0.1000249 ], dtype=float32)

# %%
from pathlib import Path
outfile = Path(PATH + "/final_embeddings_4.npy")
np.save(outfile, final_embeddings)

# %%
code_vector = np.df()
# Out:
# 'C:\\Users\\krzysztof.pieranski\\Documents\\ml\\deepbach'

# %% [markdown]
# Now let's substitute integer codes for notes with corresponding embedding vectors.

# %%
import tensorflow as tf

batch_size = 128
embedding_size = 20 # Dimension of the embedding vector.
n_neurons = 256
n_layers = 

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, [batch_size, SEQLEN, 1])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, SEQLEN, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  

  # Constant. We use pre-trained embeddings
  embeddings = tf.Constant(final_embeddings) #use this to continue learning from the saved checkpoint

  # Model.
  
  # Look up embeddings for inputs.
  input_embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  
  layers = [tf.contrib.rnn.LSTMCell(n_neurons, activation = tf.nn.relu) for layer in range(n_layers)]
  multi_layer_cell = tf.contrib.rnn.MultiRNNCell(layers)
  outputs, states = tf.nn.dynamic_rnn(multi_layer_cell)


    

  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdamOptimizer(0.001).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
for i in range(1,len(b)):
    print(permutate("abcd", b[i]))
# Out:
# abdc
# acbd
# acdb
# adbc
# adcb
# bacd
# badc
# bcad
# bcda
# bdac
# bdca
# cabd
# cadb
# cbad
# cbda
# cdab
# cdba
# dabc
# dacb
# dbac
# dbca
# dcab
# dcba

# %%
b
# Out:
# [(0, 1, 2, 3),
#  (0, 1, 3, 2),
#  (0, 2, 1, 3),
#  (0, 2, 3, 1),
#  (0, 3, 1, 2),
#  (0, 3, 2, 1),
#  (1, 0, 2, 3),
#  (1, 0, 3, 2),
#  (1, 2, 0, 3),
#  (1, 2, 3, 0),
#  (1, 3, 0, 2),
#  (1, 3, 2, 0),
#  (2, 0, 1, 3),
#  (2, 0, 3, 1),
#  (2, 1, 0, 3),
#  (2, 1, 3, 0),
#  (2, 3, 0, 1),
#  (2, 3, 1, 0),
#  (3, 0, 1, 2),
#  (3, 0, 2, 1),
#  (3, 1, 0, 2),
#  (3, 1, 2, 0),
#  (3, 2, 0, 1),
#  (3, 2, 1, 0)]

# %%
words.pop()
# Out:
# '********'

# %%
from math import log2

# %%
log2(len(dictionary))
# Out:
# 17.48772229515735

# %%
words
# Out:
# ['aabb    ', '    hhii', '  kkll  ']

# %%
batch_size = 32
sequence_size = 64
data = np.array(codetext)
data_len = data.shape[0]
# using (data_len-1) because we must provide for the sequence shifted by 1 too
nb_batches = (data_len - 1) // (batch_size * sequence_size)
assert nb_batches > 0, "Not enough data, even for a single batch. Try using a smaller batch_size."
rounded_data_len = nb_batches * batch_size * sequence_size
xdata = np.reshape(data[0:rounded_data_len], [batch_size, nb_batches * sequence_size])
ydata = np.reshape(data[1:rounded_data_len + 1], [batch_size, nb_batches * sequence_size])

# %%
xdata
# Out:
# array([[     1,      1,      1, ...,    776,     96,    153],
#        [    32,     92,    595, ...,     50,      6,      1],
#        [     1,      1,      1, ...,    154,    154,     97],
#        ...,
#        [     1,      1,      4, ...,      9,     36,     13],
#        [     9,    145,    145, ...,    806,     76,     76],
#        [     4,      4,     24, ..., 112439,   1087, 154318]])

# %%
xdata.shape
# Out:
# (32, 184768)

# %%
32*184768
# Out:
# 5912576
